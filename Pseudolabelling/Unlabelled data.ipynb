# %%
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem import PorterStemmer
import pandas as pd
from nltk.tokenize import word_tokenize
import re
import string
import numpy as np
from sklearn.utils import shuffle
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import model_selection, naive_bayes, svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_recall_fscore_support
from scipy import interp
import pickle
from xgboost import XGBClassifier

# %%
unlabel_list=[]
with open("unlabeled.txt") as fp:
    soup=BeautifulSoup(fp)
    words=soup.find_all("review_text")
    for i in range(0,len(words)-1):
        unlabel_list.append(words[i].string.strip('\n'))

# %%
df = pd.DataFrame(unlabel_list)

# %%
newdf=df.iloc[0:2000,]

# %%
newdf.shape
# Out:
# (2000, 1)

# %%
newdf.columns = ['reviews']

# %%
newdf
# Out:
#                                                 reviews
# 0     I purchased this unit due to frequent blackout...
# 1     First of all why do you want a power UPS? Ther...
# 2     We bought this to backup the iMac G5 that I go...
# 3     It's unfortunate that an earlier review indica...
# 4     I ordered 3 APC Back-UPS ES 500s on the recomm...
# 5     I replaced an older APC uninterruptible power ...
# 6     I already knew how good this product was befor...
# 7     Wish the unit had a separate online/offline li...
# 8     Electricity in my apartment would randomly go ...
# 9     It was easy to assemble and matches another on...
# 10    I have three of these CD towers, and in genera...
# 11    I've had my Wave CD storage rack for almost 5 ...
# 12    This product is a great deal.  The problem wit...
# 13    cons\ntips extremely easy on carpet and if you...
# 14    as someone else mentioned its not the sturdies...
# 15    I have never had this device fall over like ot...
# ...

# %%
newdf.to_csv("Unlabelled.csv",index=False,header=True)
